# %%
import cbir
import numpy as np
from PIL import Image

from utils import image_show

# %%
image_path = "images/elephant-12.gif"

# Load image
with Image.open(image_path) as img:
    image = np.array(img, dtype=bool) # Get grayscale from binary

# %%
out = cbir.get_similar(image)

# %%
im = out[0]
image_show(im['image'], im['filename'], im['distance'])
